# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
from pptx.enum.shapes import MSO_SHAPE
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

# ============================================================
# SETUP
# ============================================================
prs = Presentation()
prs.slide_width = Inches(13.333)
prs.slide_height = Inches(7.5)

# Color palette
DARK_BLUE = RGBColor(0x0D, 0x1B, 0x2A)
MEDIUM_BLUE = RGBColor(0x1B, 0x3A, 0x5C)
ACCENT_GOLD = RGBColor(0xC9, 0xA2, 0x27)
LIGHT_BG = RGBColor(0xF5, 0xF7, 0xFA)
WHITE = RGBColor(0xFF, 0xFF, 0xFF)
DARK_TEXT = RGBColor(0x1A, 0x1A, 0x1A)
GRAY_TEXT = RGBColor(0x55, 0x55, 0x55)
LIGHT_GRAY = RGBColor(0xE8, 0xEC, 0xF0)
GREEN_ACCENT = RGBColor(0x2E, 0x7D, 0x32)

def bg(slide, color):
    s = slide.shapes.add_shape(MSO_SHAPE.RECTANGLE, 0, 0, prs.slide_width, prs.slide_height)
    s.fill.solid(); s.fill.fore_color.rgb = color; s.line.fill.background()
    spTree = slide.shapes._spTree; sp = s._element; spTree.remove(sp); spTree.insert(2, sp)

def bar(slide, l, t, w, h, color):
    s = slide.shapes.add_shape(MSO_SHAPE.RECTANGLE, Inches(l), Inches(t), Inches(w), Inches(h))
    s.fill.solid(); s.fill.fore_color.rgb = color; s.line.fill.background()

def txt(slide, l, t, w, h, text, size, bold=False, color=DARK_TEXT, align=PP_ALIGN.LEFT, name="Calibri"):
    box = slide.shapes.add_textbox(Inches(l), Inches(t), Inches(w), Inches(h))
    tf = box.text_frame; tf.word_wrap = True
    p = tf.paragraphs[0]; p.text = text; p.font.size = Pt(size); p.font.bold = bold
    p.font.color.rgb = color; p.font.name = name; p.alignment = align
    return box

def bullet(slide, l, t, w, h, items, size=13, color=DARK_TEXT):
    box = slide.shapes.add_textbox(Inches(l), Inches(t), Inches(w), Inches(h))
    tf = box.text_frame; tf.word_wrap = True
    for i, item in enumerate(items):
        p = tf.paragraphs[0] if i == 0 else tf.add_paragraph()
        p.text = f"•  {item}"; p.font.size = Pt(size); p.font.color.rgb = color
        p.font.name = "Calibri"; p.space_after = Pt(6)
    return box

# ============================================================
# SLIDE 1: TITLE
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, DARK_BLUE)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 1.2, 2.5, 0.03, ACCENT_GOLD)
txt(s, 0.8, 1.5, 11, 0.5, "EDO STATE GOVERNMENT OF NIGERIA", 16, False, ACCENT_GOLD)
txt(s, 0.8, 1.85, 11, 0.4, "MINISTRY OF COMMUNICATION AND DIGITAL ECONOMY", 14, False, RGBColor(0xAA,0xAA,0xAA))
txt(s, 0.8, 2.6, 11.5, 1.2, "UNESCO FUNDING SUPPORT AND\nCOLLABORATION PROPOSAL", 48, True, WHITE)
txt(s, 0.8, 4.3, 10, 0.8, "Digital Transformation • Capacity Building • Data Sovereignty • Innovation • Education • Environmental Management • Cultural Heritage", 16, False, RGBColor(0xCC,0xCC,0xCC))
bar(s, 0.8, 5.8, 4, 0.03, ACCENT_GOLD)
box = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(6.1), Inches(4.5), Inches(0.7))
box.fill.solid(); box.fill.fore_color.rgb = ACCENT_GOLD; box.line.fill.background()
txt(s, 0.8, 6.22, 4.5, 0.5, "Indicative Funding: US$3,950,000", 20, True, DARK_BLUE, PP_ALIGN.CENTER)
txt(s, 8.5, 6.5, 4, 0.5, "September 2026", 12, False, RGBColor(0x88,0x88,0x88), PP_ALIGN.RIGHT)

# ============================================================
# SLIDE 2: EXECUTIVE SUMMARY
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "EXECUTIVE SUMMARY", 32, True, DARK_BLUE)
summary = ("The Edo State Government, through the Ministry of Communication and Digital Economy, seeks UNESCO funding support and strategic collaboration for a coordinated portfolio of ten digital transformation and capacity-building initiatives.\n\n"
           "The portfolio combines skills development, education technology, responsible artificial intelligence, protected data analysis, environmental management, public reporting, digital government, cultural heritage documentation and technology exhibition.\n\n"
           "The proposal is designed around a local ownership model: the Ministry will provide technical leadership and implementation capacity, while requested external support will principally address financing, specialised expertise, equipment, training resources, independent assurance, knowledge exchange and scale-up.")
txt(s, 0.8, 1.6, 8, 4.5, summary, 16, False, DARK_TEXT)
# Right highlight box
hb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(9.2), Inches(1.6), Inches(3.5), Inches(4.5))
hb.fill.solid(); hb.fill.fore_color.rgb = MEDIUM_BLUE; hb.line.fill.background()
txt(s, 9.4, 1.8, 3.1, 0.5, "KEY HIGHLIGHTS", 16, True, ACCENT_GOLD)
highlights = ["10 Integrated Digital Initiatives", "US$3.95M Indicative Budget", "36-Month Implementation", "Local Ownership Model", "Skills + Systems + Innovation", "Cross-Sector Impact"]
for i, h in enumerate(highlights):
    txt(s, 9.4, 2.3 + i*0.55, 3.1, 0.5, f"▸  {h}", 14, False, WHITE)

# ============================================================
# SLIDE 3: STRATEGIC RATIONALE
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "STRATEGIC RATIONALE & UNESCO ALIGNMENT", 32, True, DARK_BLUE)
# Left box
lb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(1.6), Inches(5.8), Inches(5.2))
lb.fill.solid(); lb.fill.fore_color.rgb = WHITE; lb.line.color.rgb = LIGHT_GRAY
txt(s, 1.0, 1.75, 5.4, 0.4, "UNESCO PRIORITIES SUPPORTED", 16, True, MEDIUM_BLUE)
priorities = ["Inclusive and quality education and lifelong learning", "Development of digital and AI competencies", "Responsible and human-centred technology", "Strengthening institutional capacity in Africa", "Environmental sustainability", "Preservation and responsible documentation of cultural heritage", "Innovation for public benefit"]
for i, p in enumerate(priorities):
    txt(s, 1.0, 2.2 + i*0.55, 5.4, 0.5, f"•  {p}", 14, False, DARK_TEXT)
# Right box
rb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(6.9), Inches(1.6), Inches(5.6), Inches(5.2))
rb.fill.solid(); rb.fill.fore_color.rgb = MEDIUM_BLUE; rb.line.fill.background()
txt(s, 7.1, 1.75, 5.2, 0.4, "ALIGNMENT WITH UNESCO FRAMEWORKS", 16, True, ACCENT_GOLD)
frameworks = ["Digital Competency Framework for Civil Servants", "AI Competency Framework for Students", "AI Competency Framework for Teachers", "Africa Portfolio: AI & Digital Innovation", "Digital Education & Capacity Development"]
for i, f in enumerate(frameworks):
    txt(s, 7.1, 2.2 + i*0.65, 5.2, 0.5, f"▸  {f}", 14, False, WHITE)
txt(s, 7.1, 5.5, 5.2, 0.8, "These frameworks provide a basis for dialogue; final eligibility and funding modality would be determined by UNESCO and relevant funding mechanisms.", 12, False, RGBColor(0xBB,0xCC,0xDD))

# ============================================================
# SLIDE 4: PROGRAMME GOAL & OBJECTIVES
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "PROGRAMME GOAL & OBJECTIVES", 32, True, DARK_BLUE)
gb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(1.5), Inches(11.7), Inches(1.1))
gb.fill.solid(); gb.fill.fore_color.rgb = MEDIUM_BLUE; gb.line.fill.background()
txt(s, 1.0, 1.6, 11.3, 0.3, "OVERALL PROGRAMME GOAL", 14, True, ACCENT_GOLD)
txt(s, 1.0, 1.95, 11.3, 0.6, "To establish a sustainable, locally led digital innovation ecosystem in Edo State that strengthens human capacity, improves public and educational services, promotes responsible AI and protected data use, supports environmental sustainability, preserves cultural knowledge, and enables government and communities to benefit from locally developed digital infrastructure.", 15, False, WHITE)

objectives = [
    ("Build Workforce", "Build a skilled local workforce in databases, software development, Python, AI and protected data analytics."),
    ("Deploy Systems", "Develop and deploy practical digital systems that address education, environment, public safety, government services and cultural heritage."),
    ("Responsible AI", "Promote responsible, privacy-aware and human-centred use of AI and digital technologies."),
    ("Institutional Capacity", "Strengthen institutional capacity and reduce long-term dependence on external software outsourcing."),
    ("Reusable Infrastructure", "Create reusable digital infrastructure, standards, documentation and knowledge assets that can be maintained locally."),
    ("Inclusive Participation", "Provide opportunities for youth, women, educators, civil servants, technical professionals and communities to participate in digital innovation."),
    ("M&E & Governance", "Establish measurable monitoring, evaluation, cybersecurity, data-governance and sustainability mechanisms across the portfolio.")
]
positions = [(0.8,2.85),(4.6,2.85),(8.4,2.85),(0.8,4.35),(4.6,4.35),(8.4,4.35),(0.8,5.85)]
for i, (title, desc) in enumerate(objectives):
    x, y = positions[i]; w = 3.6 if i < 6 else 11.7
    ob = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(x), Inches(y), Inches(w), Inches(1.3))
    ob.fill.solid(); ob.fill.fore_color.rgb = WHITE; ob.line.color.rgb = LIGHT_GRAY
    bar(s, x, y, 0.08, 1.3, ACCENT_GOLD)
    txt(s, x+0.15, y+0.1, w-0.3, 0.3, title, 13, True, MEDIUM_BLUE)
    txt(s, x+0.15, y+0.4, w-0.3, 0.8, desc, 12, False, DARK_TEXT)

# ============================================================
# SLIDE 5: PORTFOLIO OVERVIEW TABLE
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "PROJECT PORTFOLIO OVERVIEW", 32, True, DARK_BLUE)

projects = [
    ("01","Relational Database & App Development Training","$300,000","7.6%","Months 1–9"),
    ("02","Protected Data Analysis with AI & Python","$400,000","10.1%","Months 2–12"),
    ("03","Waste Disposal & Recycling Management System","$350,000","8.9%","Months 4–18"),
    ("04","Examination & Academic Performance System","$500,000","12.7%","Months 3–24"),
    ("05","Digital Technology Exhibition","$200,000","5.1%","Months 10–36"),
    ("06","Security & Environmental Reporting System","$450,000","11.4%","Months 6–24"),
    ("07","Nigeria Data Protection AI Copilot","$450,000","11.4%","Months 5–24"),
    ("08","Edo State Service Portal","$600,000","15.2%","Months 4–30"),
    ("09","Traditional Stool Management System","$300,000","7.6%","Months 7–21"),
    ("10","Digital Market Square (E-Commerce Hub)","$400,000","10.1%","Months 6–27"),
]

hb = s.shapes.add_shape(MSO_SHAPE.RECTANGLE, Inches(0.8), Inches(1.5), Inches(11.7), Inches(0.45))
hb.fill.solid(); hb.fill.fore_color.rgb = MEDIUM_BLUE; hb.line.fill.background()
txt(s, 1.0, 1.55, 0.6, 0.35, "#", 13, True, WHITE, PP_ALIGN.CENTER)
txt(s, 1.6, 1.55, 5.5, 0.35, "PROJECT", 13, True, WHITE)
txt(s, 7.3, 1.55, 1.8, 0.35, "BUDGET", 13, True, WHITE, PP_ALIGN.RIGHT)
txt(s, 9.2, 1.55, 1.2, 0.35, "SHARE", 13, True, WHITE, PP_ALIGN.RIGHT)
txt(s, 10.5, 1.55, 1.8, 0.35, "TIMELINE", 13, True, WHITE, PP_ALIGN.RIGHT)

for i, (num, name, budget, share, timeline) in enumerate(projects):
    y = 1.95 + i*0.48; bgc = WHITE if i%2==0 else LIGHT_BG
    rb = s.shapes.add_shape(MSO_SHAPE.RECTANGLE, Inches(0.8), Inches(y), Inches(11.7), Inches(0.45))
    rb.fill.solid(); rb.fill.fore_color.rgb = bgc; rb.line.color.rgb = LIGHT_GRAY; rb.line.width = Pt(0.5)
    txt(s, 1.0, y+0.05, 0.6, 0.35, num, 12, True, ACCENT_GOLD, PP_ALIGN.CENTER)
    txt(s, 1.6, y+0.05, 5.5, 0.35, name, 12, False, DARK_TEXT)
    txt(s, 7.3, y+0.05, 1.8, 0.35, budget, 12, True, DARK_TEXT, PP_ALIGN.RIGHT)
    txt(s, 9.2, y+0.05, 1.2, 0.35, share, 12, False, GRAY_TEXT, PP_ALIGN.RIGHT)
    txt(s, 10.5, y+0.05, 1.8, 0.35, timeline, 12, False, GRAY_TEXT, PP_ALIGN.RIGHT)

ty = 1.95 + 10*0.48
tb = s.shapes.add_shape(MSO_SHAPE.RECTANGLE, Inches(0.8), Inches(ty), Inches(11.7), Inches(0.5))
tb.fill.solid(); tb.fill.fore_color.rgb = DARK_BLUE; tb.line.fill.background()
txt(s, 1.0, ty+0.08, 6.0, 0.35, "TOTAL PROGRAMME REQUEST", 14, True, WHITE)
txt(s, 7.3, ty+0.08, 1.8, 0.35, "$3,950,000", 14, True, ACCENT_GOLD, PP_ALIGN.RIGHT)
txt(s, 9.2, ty+0.08, 1.2, 0.35, "100%", 14, True, ACCENT_GOLD, PP_ALIGN.RIGHT)

# ============================================================
# PROJECT SLIDES HELPER
# ============================================================
def project_slide(num, title, budget, timeline, objective, beneficiaries, deliverables, outcomes):
    s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
    bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
    txt(s, 0.8, 0.9, 11, 0.5, f"PROJECT {num}", 14, True, GRAY_TEXT)
    txt(s, 0.8, 1.15, 10, 0.5, title, 28, True, DARK_BLUE)
    
    b1 = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(1.7), Inches(2.2), Inches(0.45))
    b1.fill.solid(); b1.fill.fore_color.rgb = MEDIUM_BLUE; b1.line.fill.background()
    txt(s, 0.8, 1.78, 2.2, 0.3, f"Budget: {budget}", 13, True, WHITE, PP_ALIGN.CENTER)
    
    b2 = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(3.2), Inches(1.7), Inches(2.5), Inches(0.45))
    b2.fill.solid(); b2.fill.fore_color.rgb = DARK_BLUE; b2.line.fill.background()
    txt(s, 3.2, 1.78, 2.5, 0.3, f"Timeline: {timeline}", 13, True, WHITE, PP_ALIGN.CENTER)
    
    ob = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(2.35), Inches(11.7), Inches(0.9))
    ob.fill.solid(); ob.fill.fore_color.rgb = WHITE; ob.line.color.rgb = LIGHT_GRAY
    txt(s, 1.0, 2.45, 11.3, 0.2, "OBJECTIVE", 12, True, ACCENT_GOLD)
    txt(s, 1.0, 2.7, 11.3, 0.5, objective, 14, False, DARK_TEXT)
    
    cols = [("PRIMARY BENEFICIARIES", beneficiaries), ("KEY DELIVERABLES", deliverables), ("EXPECTED OUTCOMES", outcomes)]
    for i, (ct, ct_text) in enumerate(cols):
        x = 0.8 + i*4.1
        cb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(x), Inches(3.45), Inches(3.9), Inches(3.3))
        cb.fill.solid(); cb.fill.fore_color.rgb = WHITE; cb.line.color.rgb = LIGHT_GRAY
        txt(s, x+0.15, 3.55, 3.6, 0.25, ct, 12, True, ACCENT_GOLD)
        txt(s, x+0.15, 3.85, 3.6, 2.8, ct_text, 13, False, DARK_TEXT)

# ============================================================
# PROJECTS 1-10 (SLIDES 6-15)
# ============================================================
project_slide("01", "Relational Database Management & Application Development Training", "$300,000", "Months 1–9",
    "Build practical competence in relational database design, SQL, data modelling, administration and database-driven application development.",
    "ICT students and graduates; government ICT staff; teachers/lecturers; young developers; women and youth entering technology careers.",
    "• Training curriculum and laboratory\n• 150 trainees\n• Practical projects\n• Competency assessments\n• Mentor network\n• Training materials and certificates",
    "• At least 150 participants trained\n• 70%+ demonstrate competency\n• At least 20 practical projects completed\n• Local technical support pool established")

project_slide("02", "Protected Data Analysis Using AI & Python Programming", "$400,000", "Months 2–12",
    "Develop skills for secure data analysis, Python programming, AI-assisted analytics, privacy-aware processing and responsible data use.",
    "Government data personnel; analysts; ICT professionals; researchers; educators; selected youth and women in STEM.",
    "• Protected analytics training lab\n• 120 trainees\n• Secure-data exercises\n• Python/AI curriculum\n• Governance and privacy modules\n• Capstone projects",
    "• At least 120 trained\n• 30+ analytics prototypes\n• Improved data-governance awareness\n• Personnel capable of privacy-aware analytics")

project_slide("03", "Waste Disposal & Recycling Management System", "$350,000", "Months 4–18",
    "Digitise waste collection, disposal, recycling, environmental reporting, service-provider management, location tracking and operational monitoring.",
    "Environmental agencies; local governments; waste operators; communities; households; recyclers; policy makers.",
    "• Requirements study\n• Web/mobile platform\n• Dashboards and reporting workflow\n• GIS/location functions\n• Pilot deployment\n• Training and documentation",
    "• Operational pilot deployed\n• Faster reporting and tracking\n• Improved visibility of waste activities\n• Measurable service-provider and recycling data\n• Evidence base for environmental planning")

project_slide("04", "Examination, Assessment & Academic Performance System", "$500,000", "Months 3–24",
    "Strengthen examination administration, question management, assessment, marking, results, academic records, performance analysis and digital verification.",
    "Schools; teachers; education administrators; pupils/students; parents/guardians; quality-assurance personnel; policy makers.",
    "• End-to-end examination platform\n• Question and assessment workflows\n• Results engine and report cards\n• Performance analytics\n• Digital verification\n• Training and pilot/scale plan",
    "• Reduced manual processing\n• Improved result integrity and traceability\n• Timely academic reporting\n• Institutional performance dashboards\n• Scalable education data infrastructure")

project_slide("05", "Digital Technology Exhibition", "$200,000", "Months 10–36 (Annual)",
    "Create a public platform for demonstrating locally developed technology, AI, data systems, automation and solutions to societal challenges.",
    "Students; innovators; startups; schools; government institutions; private sector; development partners; general public.",
    "• Annual exhibition (3 cycles)\n• Live demonstrations\n• Innovation showcase\n• Workshops and policy dialogue\n• Youth challenge\n• Documentation and media materials",
    "• Three exhibition cycles delivered\n• Increased visibility of local innovation\n• Partnerships generated\n• Youth participation increased\n• Technology solutions connected to institutional needs")

project_slide("06", "Security & Societal/Environmental Reporting System", "$450,000", "Months 6–24",
    "Provide a secure reporting, tracking, analysis, escalation and management platform for appropriate security, societal and environmental reports.",
    "Government response agencies; communities; local authorities; authorised officers; civil-society and community stakeholders.",
    "• Secure reporting channels\n• Case management and workflow\n• Escalation and dashboards\n• Analytics and role-based access\n• Audit trails and privacy controls\n• Pilot deployment",
    "• Improved report routing and case visibility\n• Faster administrative response\n• Auditable workflows\n• Better aggregated evidence for planning\n• Strengthened safeguards for sensitive information")

project_slide("07", "Nigeria Data Protection Act AI Copilot", "$450,000", "Months 5–24",
    "Develop an AI-assisted compliance tool to help organisations understand and operationalise applicable Nigerian data-protection requirements.",
    "Public institutions; businesses; DPO/privacy teams; legal/compliance professionals; SMEs; civil society and technology organisations.",
    "• Knowledge base on NDPR/NDPA\n• Guided compliance workflows\n• Policy and document templates\n• Risk assessment support\n• Privacy task management\n• Human-review controls and governance",
    "• Pilot AI copilot operational\n• Compliance workflows digitised\n• Improved privacy awareness\n• Documented governance controls\n• Human-in-the-loop review model\n• Reusable compliance resources")

project_slide("08", "Edo State Service Portal", "$600,000", "Months 4–30",
    "Provide a unified digital gateway for accessing government services, applications, requests, tracking, notifications and service information.",
    "Citizens; businesses; government staff; public institutions; service providers; development partners.",
    "• Service catalogue and citizen portal\n• Application and tracking workflows\n• Notifications system\n• Identity/access integration\n• Administrative dashboard and analytics\n• Accessibility and security testing",
    "• Priority services available online\n• Reduced physical/manual transactions\n• Improved service tracking and transparency\n• Service-performance analytics\n• Scalable government digital-service platform")

project_slide("09", "Traditional Stool Management System", "$300,000", "Months 7–21",
    "Digitally document and manage information relating to traditional institutions, stools/titles, succession records, history, recognition, administration and community information.",
    "Traditional institutions; communities; cultural authorities; government cultural/administrative bodies; researchers; historians; future generations.",
    "• Data model and registry\n• Historical records module\n• Succession and documentation workflows\n• Controlled access and search\n• Preservation strategy\n• Training and governance framework",
    "• Structured digital registry\n• Improved preservation and retrieval\n• Stronger institutional documentation\n• Controlled access and governance\n• Foundation for cultural knowledge preservation")

project_slide("10", "Digital Market Square (E-Commerce Hub)", "$400,000", "Months 6–27",
    "Develop a trusted digital marketplace enabling Edo State-based businesses, artisans, farmers, creative enterprises and MSMEs to promote and sell products and services online.",
    "MSMEs; women and youth entrepreneurs; artisans; farmers and agro-processors; creative-sector businesses; cooperatives; consumers; logistics and payment partners.",
    "• E-commerce marketplace platform\n• Vendor onboarding and verification\n• Product/service catalogue\n• Merchant dashboards and order management\n• Secure payment integration\n• Delivery/logistics workflows and analytics",
    "• 1,000+ businesses onboarded\n• Increased online visibility and market access\n• New digital-sales opportunities for women and youth\n• Improved digital entrepreneurship skills\n• Sustainable state-level digital marketplace")

# ============================================================
# SLIDE 16: BUDGET VISUALIZATION
# ============================================================
fig, ax = plt.subplots(figsize=(10, 5.5))
projects_chart = ["Service Portal", "Exam System", "Security Reporting", "Data Protection AI", "Data Analysis Training", "E-Commerce Hub", "Waste Management", "Database Training", "Stool System", "Tech Exhibition"]
budgets = [600, 500, 450, 450, 400, 400, 350, 300, 300, 200]
colors_chart = ['#1B3A5C','#1B3A5C','#1B3A5C','#1B3A5C','#2E7D32','#2E7D32','#C9A227','#C9A227','#C9A227','#C9A227']
bars = ax.barh(projects_chart, budgets, color=colors_chart, edgecolor='white', height=0.65)
for bar_item, budget in zip(bars, budgets):
    ax.text(bar_item.get_width()+10, bar_item.get_y()+bar_item.get_height()/2, f'${budget:,}K', va='center', ha='left', fontsize=10, fontweight='bold', color='#1A1A1A')
ax.set_xlim(0, 750)
ax.set_xlabel('Budget (USD Thousands)', fontsize=11, color='#555555')
ax.set_title('Indicative Budget Distribution by Project', fontsize=16, fontweight='bold', color='#0D1B2A', pad=15)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#CCCCCC'); ax.spines['bottom'].set_color('#CCCCCC')
ax.tick_params(colors='#555555', labelsize=10)
ax.set_facecolor('#F5F7FA'); fig.patch.set_facecolor('#F5F7FA')
legend_elements = [Patch(facecolor='#1B3A5C', label='Digital Systems ($2.95M)'), Patch(facecolor='#2E7D32', label='Training & Skills ($800K)'), Patch(facecolor='#C9A227', label='Heritage & Innovation ($850K)')]
ax.legend(handles=legend_elements, loc='lower right', frameon=True, facecolor='white', edgecolor='#CCCCCC')
plt.tight_layout()
plt.savefig('budget_chart.png', dpi=200, bbox_inches='tight', facecolor='#F5F7FA')
plt.close()

s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "BUDGET OVERVIEW", 32, True, DARK_BLUE)
s.shapes.add_picture('budget_chart.png', Inches(1.0), Inches(1.5), width=Inches(11.3))

# ============================================================
# SLIDE 17: IMPLEMENTATION ARCHITECTURE
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "PROGRAMME IMPLEMENTATION ARCHITECTURE", 32, True, DARK_BLUE)

arch_items = [
    ("Lead Institution", "Edo State Ministry of Communication and Digital Economy", MEDIUM_BLUE),
    ("Technical Implementation", "Ministry technical teams, qualified local developers, trainers and approved specialist partners where required", DARK_BLUE),
    ("Strategic Coordination", "Inter-ministerial and agency steering arrangement covering education, environment, public service, culture, data governance and other relevant sectors", MEDIUM_BLUE),
    ("UNESCO Collaboration", "Technical dialogue, capacity-building support, knowledge exchange, standards/guidance, potential financing and independent technical engagement", DARK_BLUE),
    ("User Participation", "Structured consultations with intended users and beneficiary institutions before each production deployment", MEDIUM_BLUE),
    ("Assurance", "Cybersecurity, privacy/data-protection, accessibility, quality assurance, audit trails, documentation and independent testing", DARK_BLUE)
]

for i, (title, desc, color) in enumerate(arch_items):
    y = 1.5 + i*0.95
    ab = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(y), Inches(11.7), Inches(0.85))
    ab.fill.solid(); ab.fill.fore_color.rgb = color; ab.line.fill.background()
    txt(s, 1.0, y+0.08, 11.3, 0.25, title, 14, True, ACCENT_GOLD)
    txt(s, 1.0, y+0.35, 11.3, 0.45, desc, 13, False, WHITE)

# ============================================================
# SLIDE 18: 36-MONTH TIMELINE
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "36-MONTH HIGH-LEVEL TIMELINE", 32, True, DARK_BLUE)

phases = [
    ("Phase 1: Months 1–3", "Programme mobilisation; baseline assessment; stakeholder consultations; detailed requirements; governance; procurement planning; training curriculum development.", ACCENT_GOLD),
    ("Phase 2: Months 4–9", "Core training cohorts; system architecture and prototypes; data-governance/security design; initial education, waste and service-portal development.", MEDIUM_BLUE),
    ("Phase 3: Months 10–18", "Pilot deployments; first Digital Technology Exhibition; examination system expansion; waste and cultural registry pilots; AI/privacy copilot development.", DARK_BLUE),
    ("Phase 4: Months 19–24", "Evaluation and refinement; wider institutional onboarding; reporting platform and service portal expansion; second exhibition; advanced training.", MEDIUM_BLUE),
    ("Phase 5: Months 25–30", "Scale-up; interoperability; operational strengthening; third-party assurance; sustainability and local support arrangements.", DARK_BLUE),
    ("Phase 6: Months 31–36", "Final evaluation; knowledge products; institutional handover; maintenance model; replication/scale strategy; final exhibition and dissemination.", MEDIUM_BLUE)
]

for i, (title, desc, color) in enumerate(phases):
    y = 1.5 + i*0.95
    pb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(y), Inches(11.7), Inches(0.85))
    pb.fill.solid(); pb.fill.fore_color.rgb = color; pb.line.fill.background()
    txt(s, 1.0, y+0.08, 11.3, 0.25, title, 14, True, WHITE)
    txt(s, 1.0, y+0.35, 11.3, 0.45, desc, 13, False, WHITE)

# ============================================================
# SLIDE 19: CROSS-CUTTING PRINCIPLES
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "CROSS-CUTTING PRINCIPLES", 32, True, DARK_BLUE)

principles = [
    "Human-centred design and accessibility",
    "Responsible and ethical AI, with human oversight for consequential decisions",
    "Privacy and data protection by design",
    "Cybersecurity and role-based access controls",
    "Interoperability and avoidance of unnecessary vendor lock-in",
    "Local skills transfer, documentation and maintainability",
    "Gender and youth inclusion in training and innovation opportunities",
    "Evidence-based monitoring and measurable service outcomes",
    "Sustainability, open standards where appropriate, and responsible technology procurement"
]

for i, p in enumerate(principles):
    x = 0.8 if i < 5 else 6.9
    y = 1.6 + (i % 5) * 1.05
    pb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(x), Inches(y), Inches(5.8), Inches(0.9))
    pb.fill.solid(); pb.fill.fore_color.rgb = WHITE; pb.line.color.rgb = LIGHT_GRAY
    bar(s, x, y, 0.08, 0.9, ACCENT_GOLD)
    txt(s, x+0.15, y+0.15, 5.5, 0.6, p, 14, False, DARK_TEXT)

# ============================================================
# SLIDE 20: M&E FRAMEWORK
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "MONITORING, EVALUATION & LEARNING", 32, True, DARK_BLUE)

me_items = [
    ("Input Indicators", "Funds mobilised, trainers/technical personnel engaged, equipment and infrastructure established."),
    ("Output Indicators", "Trainees certified, systems developed, pilots completed, institutions onboarded, services digitised, reports processed and innovation events delivered."),
    ("Outcome Indicators", "Improved processing time, increased digital-service uptake, improved data quality, improved reporting visibility, stronger privacy practices, improved academic-result workflows and increased local technical capacity."),
    ("Equity Indicators", "Participation of women and youth, accessibility of digital services, geographic/institutional reach and inclusion of underserved users."),
    ("Quality Indicators", "Uptime, security-test results, user satisfaction, defect rates, audit findings, documentation completeness and maintenance readiness."),
    ("Learning", "Quarterly reviews, user feedback, pilot evaluations, annual portfolio reviews and an end-of-programme independent evaluation.")
]

for i, (title, desc) in enumerate(me_items):
    x = 0.8 if i < 3 else 6.9
    y = 1.55 + (i % 3) * 1.85
    mb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(x), Inches(y), Inches(5.8), Inches(1.7))
    mb.fill.solid(); mb.fill.fore_color.rgb = WHITE; mb.line.color.rgb = LIGHT_GRAY
    txt(s, x+0.15, y+0.12, 5.5, 0.3, title, 14, True, MEDIUM_BLUE)
    txt(s, x+0.15, y+0.45, 5.5, 1.2, desc, 13, False, DARK_TEXT)

# ============================================================
# SLIDE 21: SUSTAINABILITY & RISK MANAGEMENT
# ============================================================
s = prs.slides.add_slide(prs.slide_layouts[6]); bg(s, LIGHT_BG)
bar(s, 0, 0, 0.15, 7.5, ACCENT_GOLD); bar(s, 0.8, 0.7, 2, 0.03, ACCENT_GOLD)
txt(s, 0.8, 0.9, 11, 0.5, "SUSTAINABILITY & RISK MANAGEMENT", 32, True, DARK_BLUE)

sustain_items = [
    ("Local Technical Capacity", "In-house engineering, training of civil servants, and local software maintenance ensure systems outlive external funding.", MEDIUM_BLUE),
    ("Institutional Integration", "Aligning platforms with statutory MDA workflows to guarantee operational adoption across government bodies.", DARK_BLUE),
    ("Infrastructure & Maintenance", "Leveraging cloud infrastructure, modular open standards, and scheduled maintenance budgets for long-term scalability.", MEDIUM_BLUE),
    ("Data Privacy & Security Risks", "Mitigated via role-based access control, NDPA compliance oversight, and regular security audits.", DARK_BLUE),
    ("Adoption & Change Management", "Mitigated through active user training, stakeholder consultations, and user-centric portal interfaces.", MEDIUM_BLUE)
]

for i, (title, desc, color) in enumerate(sustain_items):
    y = 1.55 + i * 1.1
    sb = s.shapes.add_shape(MSO_SHAPE.ROUNDED_RECTANGLE, Inches(0.8), Inches(y), Inches(11.7), Inches(1.0))
    sb.fill.solid(); sb.fill.fore_color.rgb = color; sb.line.fill.background()
    txt(s, 1.0, y + 0.1, 11.3, 0.3, title, 14, True, ACCENT_GOLD)
    txt(s, 1.0, y + 0.4, 11.3, 0.5, desc, 13, False, WHITE)

# Save Presentation
prs.save("Edo_State_UNESCO_Proposal.pptx")
print("Successfully generated 'Edo_State_UNESCO_Proposal.pptx'")
# Out:
# Successfully generated 'Edo_State_UNESCO_Proposal.pptx'
